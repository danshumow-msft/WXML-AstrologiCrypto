# %%
import pandas as pd

# %%
#!pip install kerykeion
from datetime import timedelta, date, datetime
from kerykeion import AstrologicalSubject

# %%
df = pd.read_csv('application_record.csv.gz', compression='gzip')

# %%
translate = {
    "First_House":1,
    "Second_House":2,
    "Third_House":3,
    "Fourth_House":4,
    "Fifth_House":5,
    "Sixth_House":6,
    "Seventh_House":7,
    "Eigth_House":8,
    "Ninth_House":9,
    "Tenth_House":10,
    "Eleventh_House":11,
    "Twelfth_House":12
}
# Out:
#    Unnamed: 0       ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0           0  5008804           M            Y               Y             0
# 1           1  5008805           M            Y               Y             0
# 2           2  5008806           M            Y               Y             0
# 3           3  5008808           F            N               Y             0
# 4           4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
# ...

# %%
def add_astrological_date(row):
    subject = AstrologicalSubject("Subject", row['Date_Birth'].year, row['Date_Birth'].month, row['Date_Birth'].day, hour=12, minute=30, lng=80, lat=13, city="Seattle", nation="US")
    # add a new column with the astrological info
