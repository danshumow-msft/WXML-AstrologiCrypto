# %%
## install kerykeion 
# !pip install kerykeion
# Out:
# Collecting kerykeion
#   Using cached kerykeion-4.4.2-py3-none-any.whl.metadata (10 kB)
# Collecting pydantic<3.0,>=2.5 (from kerykeion)
#   Using cached pydantic-2.7.0-py3-none-any.whl.metadata (103 kB)
# Collecting pyswisseph<3.0.0.0,>=2.10.3.1 (from kerykeion)
#   Using cached pyswisseph-2.10.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (1.9 kB)
# Collecting pytz<2023.0,>=2022.7 (from kerykeion)
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from kerykeion) (2.31.0)
# Collecting requests-cache<0.10.0,>=0.9.7 (from kerykeion)
#   Using cached requests_cache-0.9.8-py3-none-any.whl.metadata (8.7 kB)
# Collecting terminaltables<4.0.0,>=3.1.10 (from kerykeion)
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3.0,>=2.5->kerykeion)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.1 (from pydantic<3.0,>=2.5->kerykeion)
#   Using cached pydantic_core-2.18.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from pydantic<3.0,>=2.5->kerykeion) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->kerykeion) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->kerykeion) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->kerykeion) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->kerykeion) (2024.2.2)
# Collecting appdirs>=1.4.4 (from requests-cache<0.10.0,>=0.9.7->kerykeion)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: attrs>=21.2 in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from requests-cache<0.10.0,>=0.9.7->kerykeion) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache<0.10.0,>=0.9.7->kerykeion)
#   Using cached cattrs-23.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting url-normalize>=1.4 (from requests-cache<0.10.0,>=0.9.7->kerykeion)
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniconda/base/envs/erdos_sp_2024/lib/python3.11/site-packages (from url-normalize>=1.4->requests-cache<0.10.0,>=0.9.7->kerykeion) (1.16.0)
# Using cached kerykeion-4.4.2-py3-none-any.whl (303 kB)
# Using cached pydantic-2.7.0-py3-none-any.whl (407 kB)
# Using cached pydantic_core-2.18.1-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pyswisseph-2.10.3.2-cp311-cp311-macosx_10_9_universal2.whl (793 kB)
# Using cached pytz-2022.7.1-py2.py3-none-any.whl (499 kB)
# Using cached requests_cache-0.9.8-py3-none-any.whl (48 kB)
# Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cattrs-23.2.3-py3-none-any.whl (57 kB)
# Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: pytz, appdirs, url-normalize, terminaltables, pyswisseph, pydantic-core, cattrs, annotated-types, requests-cache, pydantic, kerykeion
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
# Successfully installed annotated-types-0.6.0 appdirs-1.4.4 cattrs-23.2.3 kerykeion-4.4.2 pydantic-2.7.0 pydantic-core-2.18.1 pyswisseph-2.10.3.2 pytz-2022.7.1 requests-cache-0.9.8 terminaltables-3.1.10 url-normalize-1.4.3

# %%
import pandas as pd
from datetime import timedelta, date, datetime
from kerykeion import AstrologicalSubject
pd.options.mode.copy_on_write = True

# %%
#df = pd.read_csv("application_record.csv.zip", compression="zip")
df = pd.read_csv("../credit_cleaned.csv")

# %%
df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            0             1                1             0          427500.0
# 1            0             1                1             0          112500.0
# 2            1             0                1             0          270000.0
# 3            1             0                1             0          283500.0
# 4            0             1                1             0          270000.0
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  \
# 0                    3                   0                  0      -12005
# 1                    1                   1                  1      -21474
# 2                    1                   2                  1      -19110
# 3                    3                   3                  1      -22464
# 4                    3                   1                  1      -16872
#
#    DAYS_EMPLOYED  CNT_FAM_MEMBERS
# 0          -4542              2.0
# 1          -1134              2.0
# 2          -3051              1.0
# 3         365243              1.0
# 4           -769              2.0

# %%
date_posted = pd.to_datetime('2020-03-24')

# %%
df["Date_Birth"] = date_posted + pd.to_timedelta(df['DAYS_BIRTH'], unit='D')

# %%
df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            0             1                1             0          427500.0
# 1            0             1                1             0          112500.0
# 2            1             0                1             0          270000.0
# 3            1             0                1             0          283500.0
# 4            0             1                1             0          270000.0
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  \
# 0                    3                   0                  0      -12005
# 1                    1                   1                  1      -21474
# 2                    1                   2                  1      -19110
# 3                    3                   3                  1      -22464
# 4                    3                   1                  1      -16872
#
#    DAYS_EMPLOYED  CNT_FAM_MEMBERS Date_Birth
# 0          -4542              2.0 1987-05-12
# 1          -1134              2.0 1961-06-08
# 2          -3051              1.0 1967-11-28
# 3         365243              1.0 1958-09-22
# 4           -769              2.0 1974-01-13

# %%
mask = df['DAYS_EMPLOYED'] <=0

# %%
df = df[mask]

# %%
df["Date_Employed"] = date_posted + pd.to_timedelta(df['DAYS_EMPLOYED'], unit='D')

# %%
df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            0             1                1             0          427500.0
# 1            0             1                1             0          112500.0
# 2            1             0                1             0          270000.0
# 4            0             1                1             0          270000.0
# 5            0             1                1             0          135000.0
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  \
# 0                    3                   0                  0      -12005
# 1                    1                   1                  1      -21474
# 2                    1                   2                  1      -19110
# 4                    3                   1                  1      -16872
# 5                    1                   1                  1      -17778
#
#    DAYS_EMPLOYED  CNT_FAM_MEMBERS Date_Birth Date_Employed
# 0          -4542              2.0 1987-05-12    2007-10-17
# 1          -1134              2.0 1961-06-08    2017-02-14
# 2          -3051              1.0 1967-11-28    2011-11-16
# 4           -769              2.0 1974-01-13    2018-02-14
# 5          -1194              2.0 1971-07-22    2016-12-16

# %%
#df.to_csv("credit_cleaned.csv.gz", compression='gzip')

# %%
#df = df.drop(columns=['DAYS_EMPLOYED','DAYS_BIRTH'])

# %%
translate = {
  "Ari": 1,
  "Tau": 2,
  "Gem": 3,
  "Can": 4,
  "Leo": 5,
  "Vir": 6,
  "Lib": 7,
  "Sco": 8,
  "Sag": 9,
  "Cap": 10,
  "Aqu": 11,
  "Pis": 12
}

# %%
# use kerykeion to find sign

def add_astrological_info(row):
    subject = AstrologicalSubject("Subject", year = row['Date_Birth'].year, month = row['Date_Birth'].month, day = row['Date_Birth'].day, hour = 12, minute = 17, lng=80, lat=13, city="Chennai", nation="IN")
    astro_data = [
        translate[subject.sun.sign], translate[subject.moon.sign], translate[subject.mercury.sign],
        translate[subject.venus.sign],translate[subject.mars.sign], translate[subject.jupiter.sign],
        translate[subject.saturn.sign], translate[subject.uranus.sign], translate[subject.neptune.sign]
    ]
    return astro_data

# %%
df['Sign_Birth'] = df.apply(lambda row: add_astrological_info(row), axis=1)

# %%
def higher_astro_encoding(row):
    # we want base 12 in each entry
    # for example a list [1,2,4] should map to (4-1)*1 + (2-1)*12 + (1-1)*12^2
    A= row['Sign_Birth']
    N = len(A)
    num = 0
    for i in range(N):
        num += (12**i)*(A[i]-1)
    return num

# %%
def lower_astro_encoding(row):
    # we want base 12 in each entry
    # for example a list [1,2,4] should map to (4-1)*1 + (2-1)*12 + (1-1)*12^2
    A= row['Sign_Birth']
    N = len(A)
    num = 0
    for i in range(N):
        num += (12**(N-i-1))*(A[i]-1)
    return num

# %%
df['higher_Sign_Birth'] = df.apply(lambda row: higher_astro_encoding(row), axis=1)
df['lower_Sign_Birth'] = df.apply(lambda row: lower_astro_encoding(row), axis=1)

# %%
df['DAYS_BIRTH'] = df['DAYS_BIRTH']*(-1)

# %%
df['DAYS_EMPLOYED'] = df['DAYS_EMPLOYED']*(-1)
df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            0             1                1             0          427500.0
# 1            0             1                1             0          112500.0
# 2            1             0                1             0          270000.0
# 4            0             1                1             0          270000.0
# 5            0             1                1             0          135000.0
#
#    NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  \
# 0                    3                   0                  0       12005
# 1                    1                   1                  1       21474
# 2                    1                   2                  1       19110
# 4                    3                   1                  1       16872
# 5                    1                   1                  1       17778
#
#    DAYS_EMPLOYED  CNT_FAM_MEMBERS Date_Birth Date_Employed  \
# 0           4542              2.0 1987-05-12    2007-10-17
# 1           1134              2.0 1961-06-08    2017-02-14
# 2           3051              1.0 1967-11-28    2011-11-16
# 4            769              2.0 1974-01-13    2018-02-14
# 5           1194              2.0 1971-07-22    2016-12-16
#
#                         Sign_Birth  higher_Sign_Birth  lower_Sign_Birth
# 0     [2, 8, 2, 1, 3, 1, 9, 9, 10]         4180419301         683833065
# 1    [3, 1, 4, 2, 5, 11, 10, 5, 8]         3182646386         869271751
# 2     [9, 7, 8, 7, 10, 6, 1, 6, 8]         3190473152        3677434627
# 4  [10, 6, 10, 11, 2, 11, 3, 7, 9]         3663344085        4078394864
# 5     [4, 4, 5, 4, 11, 8, 3, 7, 9]         3662771367        1410350768

# %%
df.to_csv('credit_astro.csv', index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
important_cols = ['AMT_INCOME_TOTAL', 'NAME_EDUCATION_TYPE','higher_Sign_Birth', 'lower_Sign_Birth']

sns.pairplot(df[important_cols])
